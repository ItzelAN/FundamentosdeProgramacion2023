# %% [markdown]
# ---
#
#
# # **ACTIVIDAD 1**
#
# ## Tipos de datos, variables y operadores
#
# ###**NOTA** 🌟: Para realizar la actividad y que le permita guardar cambios es necesario **sacarle una copia** al archivo original. Recuerde que todo archivo al que le saque copia se ira directamente a su carpeta de **Colab Notebooks** dentro de su **Drive**. Una vez terminado, **descargue** su archivo de actividad con extensión **.ipynb** y adjúntelo a la tarea correspondiente en la plataforma de [Formación docente cucei](http://formaciondocente.cucei.udg.mx/mod/assign/view.php?id=41419).
#
# ---

# %% [markdown]
# # **Tipos de datos**
#
# > Utilice el método `type( )` para determinar que tipo de dato se tiene en los siguientes ejercicios.

# %% [markdown]
# ###**Ejercicio 1**
#
# ####¿Qué tipo de dato es 1.75j?

# %% [markdown]
# ###**Ejercicio 2**
#
# ####¿Qué tipo de dato es int('12')?

# %% [markdown]
# ###**Ejercicio 3**
#
# ####¿Qué tipo de dato es 'True'?

# %% [markdown]
# # **Variables**
#
# ---
#
#
# > Realice el ejercicio con manejo de variables. Recuerde nombrar a sus variables de forma correcta para evitar errores.

# %% [markdown]
# ###**Ejercicio 1**
#
# ####Declare las siguientes variables de tipo cadena y asignele sus datos personales:
#
# * Nombre
# * Edad
# * Nombramiento
# * Codigo
# * Grado de estudios
#
# ####Una vez declaradas las variables y sus respectivos valores, imprima en pantalla la siguiente frase:
#
#
#
# > ¡Hola Mundo! Mi nombre es (Agregar variable Nombre) tengo (Agregar variable Edad) años. Trabajo en la Universidad de Guadalajara, tengo el nombramiento de (Agregar variable Nombramiento), mi código es (Agregar variable Código), y mi grado de estudios es (Agregar variable Grado de estudios).

# %% [markdown]
# # **Operadores**
#
# ---
#
#
#
# > Resuelva los siguientes ejercicios empleando operadores.

# %% [markdown]
# ###**Ejercicio 1:**
#
# ####Calcule las siguientes expresiones e imprima en pantalla que valor tienen `x, y, z`:
#
#
# ```
# x = 17 - 2 * 4 + 5
# y = (140 / x) ** 2
# z = y % x
#
# ```

# %% [markdown]
# ###**Ejercicio 2:**
#
# ####Tome los valores de `x, y` del **Ejercicio 1** de operadores, realice las siguientes comparaciones e imprima el resultado en pantalla:
#
# ```
# x == y
# x != y
# y > x
# y < x
# x >= y
# x <= y
# ```

# %% [markdown]
# ###**Ejercicio 3**
#
# ####Tome los valores de `x,y,z` del **Ejercicio 1** de operadores, realice las siguientes operaciones lógicas e imprima el resultado en pantalla:
#
#
# ```
# x < y and y > z
# x != y or x == z
# not(x <= y and y >= z)
# ```
