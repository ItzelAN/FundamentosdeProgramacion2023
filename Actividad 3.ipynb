# %% [markdown]
# ---
#
#
# # **ACTIVIDAD 3**
#
# ## Cadenas y listas
#
# ###**NOTA** 🌟: Para realizar la actividad y que le permita guardar cambios es necesario **sacarle una copia** al archivo original. Recuerde que todo archivo al que le saque copia se ira directamente a su carpeta de **Colab Notebooks** dentro de su **Drive**. Una vez terminado, descargue su archivo de actividad con extensión **.ipynb** y adjúntelo a la tarea correspondiente en el curso de la plataforma de [Formación docente cucei](http://formaciondocente.cucei.udg.mx/mod/assign/view.php?id=41468).
#
# ---

# %% [markdown]
# # **Cadenas**
#
#
# ---

# %% [markdown]
# ###**Ejercicio 1**
#
# ####Utilice el método `upper()` para convertir la cadena **"¡Buenos días!"** a mayúsculas.

# %% [markdown]
# ###**Ejercicio 2**
#
# ####Utilice la divisón de cadenas `[:]` para imprimir la subcadena **"Bue"** del índice 1 al 3 de la cadena **"¡Buenos días!"**.

# %% [markdown]
# ###**Ejercicio 3**
#
# ####Utilice el método `replace()` para sustituir el carácter **d** por **f** de la cadena "¡Buenos días!".

# %% [markdown]
# # **Listas**
#
# ---

# %% [markdown]
# ###**Ejercicio 1**
#
# ####Cambia el valor de **"manzana"** a **"kiwi"**, en la lista de frutas e imprime el resultado.
#
#
# ```
# frutas = ["manzana", "plátano", "cereza"]
# ```

# %% [markdown]
# ###**Ejercicio 2**
#
# ####Utiliza el método `insert()` para añadir a **"naranja"** en la posición **0** de la lista de frutas e imprime el resultado.
# ```
# frutas = ["manzana", "plátano", "cereza"]
# ```

# %% [markdown]
# ###**Ejercicio 3:**
#
# ####Utiliza el método `remove()` para eliminar a **"cereza"** de la lista de frutas e imprime el resultado.
# ```
# frutas = ["manzana", "plátano", "cereza"]
# ```

# %% [markdown]
# ###**Ejercicio 4:**
#
# ####Utiliza el método `sort()` para ordenar los elementos de la lista de frutas e imprime el resultado.
# ```
# frutas = ["manzana", "plátano", "cereza"]
# ```
