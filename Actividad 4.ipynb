# %% [markdown]
# ---
#
#
# # **ACTIVIDAD 4**
#
# ## Conjuntos y tuplas
#
# ###**NOTA** 🌟: Para realizar la actividad y que le permita guardar cambios es necesario **sacarle una copia** al archivo original. Recuerde que todo archivo al que le saque copia se ira directamente a su carpeta de **Colab Notebooks** dentro de su **Drive**. Una vez terminado, descargue su archivo de actividad con extensión **.ipynb** y adjúntelo a la tarea correspondiente en el curso de la plataforma de [Formación docente cucei](http://formaciondocente.cucei.udg.mx/mod/assign/view.php?id=41490).
#
# ---

# %% [markdown]
# # **Conjuntos**
#
#
# ---

# %% [markdown]
# ###**Ejercicio 1**
#
#
# ####El congreso **"DIVTIC 2023"** ofrece los siguientes talleres: Programación en Python, Diseño básico en Inkscape y Manejo básico de Excel. Para cada curso se tiene el siguiente registro de asistentes:
#
#
# ```
# Python = {'Alma', 'Gabriel', 'Fernando', 'Perla', 'Marcela', 'Luis'}
#
# Inkscape = {'Pedro', 'Laura', 'Luis', 'Ana', 'Claudia', 'Gabriel'}
#
# Excel = {'Luis', 'José', 'Fátima', 'Carlos', 'Gabriel', 'Graciela'}
# ```
#
#
#
# ####De acuerdo al registro realice lo siguiente utilizando operaciones de conjuntos:
#
#
# 1.   Muestre los nombres de los asistentes que se registraron a los tres cursos. Utilice la **intersección** de conjuntos.
#
# 2.   Muestre los nombres de los asistentes que se registraron solo al curso de Python y no a otro curso. Utilice la **diferencia** de conjuntos.
# 3.   Muestre los nombres de los asistentes que se registraron a los cursos de Inkscape y Excel **exceptuando** a aquellos que se registraron a los dos cursos. Utilice la **diferencia simétrica** de conjuntos.
# 4.   Muestre los nombres de todos los asistentes del congreso. Utilice a la **unión** de conjuntos.
# 5.   Muestre la cantidad total de asistentes al evento. Utilice al método `len()`.
#
# ####**Ejemplo de salida en pantalla**
#
# ```
# Asistentes registrados en los tres talleres: {'Luis', 'Gabriel'}
#
# Asistentes registrados solo en el taller de Python y no en otro taller:
# {'Alma', 'Marcela', 'Fernando', 'Perla'}
#
# Asistentes registrados en los talleres de Inkscape y Excel pero no en ambos:
# {'Fátima', 'Ana', 'Laura', 'José', 'Carlos', 'Claudia', 'Graciela', 'Pedro'}
#
# Nombres de todos los asistentes:
# {'Alma', 'Marcela', 'Fátima', 'Luis', 'Claudia', 'Gabriel', 'Graciela', 'Carlos', 'José', 'Ana', 'Laura', 'Pedro', 'Fernando', 'Perla'}
#
# Total de asistentes al evento: 14
# ```

# %% [markdown]
# # **Tuplas**
#
# ---

# %% [markdown]
# ###**Ejercicio 1**
#
# ####Utiliza un rango de índices `[:]` para imprimir el tercer, cuarto y quinto elemento de la tupla.
# ```
# frutas = ("manzana", "plátano", "cereza", "naranja", "kiwi", "melón", "mango")
# ```

# %% [markdown]
# ###**Ejercicio 2**
#
# ####Declare una tupla con los valores indicados, transforme la tupla a lista y realice lo siguiente:
#
# ```
# frutas = ("manzana", "plátano", "cereza")
# ```
#
# 1.  Modifique el valor de **"manzana"** a **"kiwi"**.
#
# 2.  Agregue el valor de **"pera"**.
#
# 3.  Elimine el valor de **"plátano"**.
#
# ####Hecho esto transforme la lista en tupla e imprima el resultado.

# %% [markdown]
# ###**Ejercicio 3:**
#
# ####Utiliza el método de **`desempaquetado`** para asignar a variables los valores de la tupla e imprima el resultado.
# ```
# compras = ("Pan", "Huevo", "Carne", "Leche", "Jamón", "Queso")
# ```
# ####**Nota:** Puede utilizar el método con asterisco si lo desea.
