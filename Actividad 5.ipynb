# %% [markdown]
# ---
#
#
# # **ACTIVIDAD 5**
#
# ## Diccionarios
#
# ###**NOTA** 🌟: Para realizar la actividad y que le permita guardar cambios es necesario **sacarle una copia** al archivo original. Recuerde que todo archivo al que le saque copia se ira directamente a su carpeta de **Colab Notebooks** dentro de su **Drive**. Una vez terminado, descargue su archivo de actividad con extensión **.ipynb** y adjúntelo a la tarea correspondiente en el curso de la plataforma de [Formación docente cucei](http://formaciondocente.cucei.udg.mx/mod/assign/view.php?id=41591).
#
# ---

# %% [markdown]
# ###**Ejercicio 1**
#
#
# ####Solicite un número entero por teclado y genere un diccionario cuyas claves sean desde el número 1 hasta el número indicado, y los valores sean los cuadrados de las claves. Imprima al diccionario completo con sus claves y valores.
#
# ####**Ejemplo de salida en pantalla:**
#
#
# ```
# Ingrese un número entero: 7
#
# Su diccionario a partir del rango del 1 al 7 es:
#
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49}
#
# ```

# %% [markdown]
# ###**Ejercicio 2**
#
#
# ####Tome el diccionario descrito a continuación:
#
# ```
# Productos = dict(Lacteos = ["Queso", "Crema", "Leche"], Panaderia = ["Pan Tostado", "Pan de caja", "Pan para hamburguesa"])
# ```
#
# ####Y realice lo siguiente:
#
#
#
# 1.   Agregue la siguiente clave y valores por medio del método **`setdefault()`**.
# ```
# Frutas = ['Kiwi','Manzana','Ciruela','Mango']
# ```
# 2.   Elimine al elemento en el índice **1** de la lista que se encuentra en la clave **'Panadería'** utilizando la función **`del`**. Siguiendo este ejemplo:
# ```
# del Diccionario['Clave'][Índice de la lista a borrar]
# ```
#
# 3.   Imprima los pares de **`clave - valor`** mediante la **iteración** del diccionario con la función **`items()`**. Ejemplo de salida:
# ```
# Lacteos : ['Queso', 'Crema', 'Leche']
# Panaderia : ['Pan Tostado', 'Pan para hamburguesa']
# Frutas : ['Kiwi', 'Manzana', 'Ciruela', 'Mango']
# ```
